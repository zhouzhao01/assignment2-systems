# %%
import timeit
import time

# %%
time_1 = timeit.default_timer()
time.sleep(5)
time_2 = timeit.default_timer()
print(time_2 - time_1)
# Out:
# 10.000396745977923

# %%
time_1 = timeit.default_timer()
time.sleep(5)
print(timeit.default_timer() - time_1)
# Out:
# 5.000453183893114
